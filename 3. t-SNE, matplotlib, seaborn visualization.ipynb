# %% [markdown]
# # 3. t-SNE, matplotlib, seaborn visualization

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
pwd()
# Out:
# 'C:\\Users\\sayan\\Google Drive\\Sayan EDA\\Data Visualization_Statistics'

# %%
data = pd.read_csv('countries.csv')
print(data.head())
print(data.tail())
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 1699  Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700  Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701  Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702  Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703  Zimbabwe    Africa  2007          43.487    12311143    469.709298

# %%
# data['country']
data.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
# 7       Afghanistan
# 8       Afghanistan
# 9       Afghanistan
# 10      Afghanistan
# 11      Afghanistan
# 12          Albania
# 13          Albania
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
# 19          Albania
# 20          Albania
# 21          Albania
# 22          Albania
# 23          Albania
# 24          Algeria
# 25          Algeria
# 26          Algeria
# 27          Algeria
# 28          Algeria
# 29          Algeria
#            ...
# 1674    Yemen, Rep.
# 1675    Yemen, Rep.
# 1676    Yemen, Rep.
# 1677    Yemen, Rep.
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# 1680         Zambia
# 1681         Zambia
# 1682         Zambia
# 1683         Zambia
# 1684         Zambia
# 1685         Zambia
# 1686         Zambia
# 1687         Zambia
# 1688         Zambia
# 1689         Zambia
# 1690         Zambia
# 1691         Zambia
# 1692       Zimbabwe
# 1693       Zimbabwe
# 1694       Zimbabwe
# 1695       Zimbabwe
# 1696       Zimbabwe
# 1697       Zimbabwe
# 1698       Zimbabwe
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
afghanistan = data[data.country == 'Afghanistan']

# %%
plt.plot(afghanistan.year, afghanistan.gdpPerCapita)
plt.title("Afghanistan's GDP Per Capita")
plt.show()

# %%
from matplotlib import pyplot as plt

# NOTE: The pyplot module is a simple interface for matplotlib.

# %%
plt.plot([1, 2, 3], [1, 4, 9])
plt.xlabel('this is x axis')
plt.ylabel('this is y axis')
plt.title('This is the plot title.')
plt.show()

# %%
plt.plot([1, 2, 3], [1, 4, 9])
plt.plot([1, 2, 3], [10, 20, 30])
plt.legend(['Data Set 1', 'Data Set 2'])
# plt.legend() takes a list as an argument.
plt.show()
#  plt.savefig('exported_image')

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = {'year': [2008, 2012, 2016],
        'attendees': [112, 321, 729],
        'average age': [24, 43, 31]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    year  attendees  average age
# 0  2008        112           24
# 1  2012        321           43
# 2  2016        729           31

# %%
df['year']
# Out:
# 0    2008
# 1    2012
# 2    2016
# Name: year, dtype: int64

# %%
type(df['year'])
# Out:
# pandas.core.series.Series

# %%
earlier_than_2013 = df['year'] < 2013

# %%
df[earlier_than_2013]
# Out:
#    year  attendees  average age
# 0  2008        112           24
# 1  2012        321           43

# %%
plt.plot(df['year'], df['attendees'])
plt.plot(df['year'], df['average age'])
plt.legend(['attendees', 'average age'])
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
set(data.continent)
# Out:
# {'Africa', 'Americas', 'Asia', 'Europe', 'Oceania'}

# %%
data_2007 = data[data.year == 2007]

# %%
asia_2007 = data_2007[data_2007.continent == 'Asia']
europe_2007 = data_2007[data_2007.continent == 'Europe']

# %%
asia_2007.head()
# Out:
#          country continent  year  lifeExpectancy  population  gdpPerCapita
# 11   Afghanistan      Asia  2007          43.828    31889923    974.580338
# 95       Bahrain      Asia  2007          75.635      708573  29796.048340
# 107   Bangladesh      Asia  2007          64.062   150448339   1391.253792
# 227     Cambodia      Asia  2007          59.723    14131858   1713.778686
# 299        China      Asia  2007          72.961  1318683096   4959.114854

# %%
europe_2007.head()
# Out:
#                     country continent  year  lifeExpectancy  population  \
# 23                  Albania    Europe  2007          76.423     3600523
# 83                  Austria    Europe  2007          79.829     8199783
# 119                 Belgium    Europe  2007          79.441    10392226
# 155  Bosnia and Herzegovina    Europe  2007          74.852     4552198
# 191                Bulgaria    Europe  2007          73.005     7322858
#
#      gdpPerCapita
# 23    5937.029526
# 83   36126.492700
# 119  33692.605080
# 155   7446.298803
# 191  10680.792820

# %%
print(len(set(asia_2007.country)))
print(len(set(europe_2007.country)))
# Out:
# 33
# 30

# %%
print('Mean GDP Per Capita in Asia:')
print(asia_2007.gdpPerCapita.mean())
print('Mean GDP Per Capita in Europe:')
print(europe_2007.gdpPerCapita.mean())
print('Median GDP Per Capita in Asia:')
print(asia_2007.gdpPerCapita.median())
print('Median GDP Per Capita in Europe:')
print(europe_2007.gdpPerCapita.median())
# Out:
# Mean GDP Per Capita in Asia:
# 12473.02687013333
# Mean GDP Per Capita in Europe:
# 25054.481635933327
# Median GDP Per Capita in Asia:
# 4471.061906
# Median GDP Per Capita in Europe:
# 28054.06579

# %%
plt.subplot(2, 1, 1) # subplot(211)
plt.title('Distribution of GDP Per Capita')
plt.hist(asia_2007.gdpPerCapita, 7, range=(0, 50000), edgecolor='black')
plt.ylabel('Asia')
plt.subplot(2, 1, 2)
plt.hist(europe_2007.gdpPerCapita, 7, range=(0, 50000), edgecolor='black')
plt.ylabel('Europe')
plt.show()

# %% [markdown]
# ### Problem: Compare life expectancy's distributions of Europe and Americas in 1997.
# Use pyplot's hist() function to draw histograms and subplot() to compare them.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
data_1997 = data[data.year == 1997]
americas_1997 = data_1997[data_1997.continent == 'Americas']
europe_1997 = data_1997[data_1997.continent == 'Europe']

# %%
print(len(set(americas_1997.country)))
print(len(set(europe_1997.country)))
# Out:
# 25
# 30

# %%
print('Mean Life Expectancy in Americas:')
print(americas_1997.lifeExpectancy.mean())
print('Mean Life Expectancy in Europe: ')
print(europe_1997.lifeExpectancy.mean())
print('Median Life Expectancy in Americas:')
print(americas_1997.lifeExpectancy.median())
print('Median Life Expectancy in Europe: ')
print(europe_1997.lifeExpectancy.median())
# Out:
# Mean Life Expectancy in Americas:
# 71.15048
# Mean Life Expectancy in Europe:
# 75.50516666666667
# Median Life Expectancy in Americas:
# 72.146
# Median Life Expectancy in Europe:
# 76.116

# %%
bins = 2
plt.subplot(211)
plt.title('Distribution of Life Expectancy')
plt.hist(americas_1997.lifeExpectancy, bins, range=(55, 85), edgecolor='black')
plt.ylabel('Americas')

plt.subplot(212)
plt.hist(europe_1997.lifeExpectancy, bins, range=(55, 85), edgecolor='black')
plt.ylabel('Europe')
plt.show()

# %%
americas_1997[americas_1997.lifeExpectancy < 65]
# Out:
#      country continent  year  lifeExpectancy  population  gdpPerCapita
# 141  Bolivia  Americas  1997          62.050     7693188   3326.143191
# 645    Haiti  Americas  1997          56.671     6913545   1341.726931

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
us = data[data.country == 'United States']
us.head()
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 1608  United States  Americas  1952           68.44   157553000   13990.48208
# 1609  United States  Americas  1957           69.49   171984000   14847.12712
# 1610  United States  Americas  1962           70.21   186538000   16173.14586
# 1611  United States  Americas  1967           70.76   198712000   19530.36557
# 1612  United States  Americas  1972           71.34   209896000   21806.03594

# %%
plt.plot(us.year, us.gdpPerCapita)
plt.title('GDP Per Capita Growth in the U.S.')
plt.xlabel('year')
plt.ylabel('GDP per capita')
plt.show()

# %%
china = data[data.country == 'China']

# %%
plt.plot(us.year, us.gdpPerCapita)
plt.plot(china.year, china.gdpPerCapita)
plt.legend(['United States', 'China'])
plt.xlabel('year')
plt.ylabel('GDP per capita')
plt.show()

# %%
us.gdpPerCapita.iloc[0]
# Out:
# 13990.482080000002

# %%
us_growth = us.gdpPerCapita / us.gdpPerCapita.iloc[0] * 100
china_growth = china.gdpPerCapita / china.gdpPerCapita.iloc[0] * 100

# %%
plt.title('GDP Per Capita Growth (first year = 100)')
plt.plot(us.year, us_growth)
plt.plot(china.year, china_growth)
plt.legend(['United States', 'China'])
plt.xlabel('year')
plt.ylabel('GDP per capita growth')
plt.show()

# %% [markdown]
# ### Problem: Compare population growth in the U.S. and China.
# Compare them both in terms of absolute growth and relative growth.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
us = data[data.country == 'United States']
china = data[data.country == 'China']

# %%
plt.plot(us.year, us.population / 10**6)
plt.plot(china.year, china.population / 10**6)
plt.title('Population Growth in the U.S. and China (in millions)')
plt.legend(['United States', 'China'])
plt.xlabel('year')
plt.ylabel('population')
plt.show()

# %%
us_growth = us.population / us.population.iloc[0] * 100
china_growth = china.population / china.population.iloc[0] * 100

plt.plot(us.year, us_growth)
plt.plot(china.year, china_growth)

plt.title('Population Growth in the U.S. and China (first year = 100)')
plt.legend(['United States', 'China'])
plt.xlabel('year')
plt.ylabel('population')

plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
data_2007 = data[data.year == 2007]
data_2007.head()
# Out:
#         country continent  year  lifeExpectancy  population  gdpPerCapita
# 11  Afghanistan      Asia  2007          43.828    31889923    974.580338
# 23      Albania    Europe  2007          76.423     3600523   5937.029526
# 35      Algeria    Africa  2007          72.301    33333216   6223.367465
# 47       Angola    Africa  2007          42.731    12420476   4797.231267
# 59    Argentina  Americas  2007          75.320    40301927  12779.379640

# %%
plt.scatter(data_2007.gdpPerCapita, data_2007.lifeExpectancy, 5)
plt.title('GDP Per Capita and Life Expectancy in 2007')
plt.xlabel('GDP Per Capita ($)')
plt.ylabel('Life Expectancy')
plt.show()

# %%
data_2007.gdpPerCapita.corr(data_2007.lifeExpectancy)
# Out:
# 0.6786623986777587

# %%
np.log10([10, 100, 1000])
# Out:
# array([1., 2., 3.])

# %%
plt.scatter(np.log10(data_2007.gdpPerCapita), data_2007.lifeExpectancy)
plt.show()

# %%
np.log10(data_2007.gdpPerCapita).corr(data_2007.lifeExpectancy)
# Out:
# 0.8089802514849209

# %%
data_2007.gdpPerCapita.corr(data_2007.lifeExpectancy)
# Out:
# 0.6786623986777587

# %%
# Change the line plot below to a scatter plot
plt.scatter(data_2007.gdpPerCapita, data_2007.lifeExpectancy)

# Put the x-axis on a logarithmic scale
plt.xscale('log')

# Show plot
plt.show()

# %%
years_sorted = sorted(set(data.year))

# %%
for given_year in years_sorted:
    data_year = data[data.year == given_year]
    plt.scatter(data_year.gdpPerCapita, data_year.lifeExpectancy, 5)
    plt.title(given_year)
    plt.xlim(0, 60000)
    plt.ylim(25, 85)
    plt.xlabel('GDP Per Capita')
    plt.ylabel('Life Expectancy')
    plt.show()
    plt.savefig(str(given_year), dpi=200) # dpi = dots per inch
    plt.clf() # We need this line to clear the current plot.

# %%
data[data.gdpPerCapita > 60000]
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 852  Kuwait      Asia  1952          55.565      160000  108382.35290
# 853  Kuwait      Asia  1957          58.033      212846  113523.13290
# 854  Kuwait      Asia  1962          60.470      358266   95458.11176
# 855  Kuwait      Asia  1967          64.624      575003   80894.88326
# 856  Kuwait      Asia  1972          67.712      841934  109347.86700

# %%
for given_year in years_sorted:
    data_year = data[data.year == given_year]
    plt.scatter(np.log10(data_year.gdpPerCapita), data_year.lifeExpectancy, 5)
    plt.title(given_year)
    plt.xlim(2, 5)
    plt.ylim(25, 85)
    plt.xlabel('GDP Per Capita (log scale)')
    plt.ylabel('Life Expectancy')
    plt.show()
    plt.savefig('log_' + str(given_year), dpi=200)
    plt.clf()

# %% [markdown]
# ### Problem: Find the relationship between life expectancy and GDP (NOT GDP per capita).
# Use plt.scatter() and np.log10().

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
data_2007 = data[data.year == 2007]
gdp_in_billions = (data_2007.gdpPerCapita * data_2007.population) / 10**9
plt.scatter(gdp_in_billions, data_2007.lifeExpectancy, 5)
plt.show()

# %%
plt.scatter(np.log10(gdp_in_billions), data_2007.lifeExpectancy, 5)
plt.show()

# %%
plt.scatter(np.log10(data_2007.gdpPerCapita), data_2007.lifeExpectancy, 5)
plt.show()

# %%
print('Correlation between log10 of GDP and life expectancy:')
print(np.log10(gdp_in_billions).corr(data_2007.lifeExpectancy))
print('Correlation between log10 of GDP per capita and life expectancy:')
print(np.log10(data_2007.gdpPerCapita).corr(data_2007.lifeExpectancy))
# Out:
# Correlation between log10 of GDP and life expectancy:
# 0.600040537644758
# Correlation between log10 of GDP per capita and life expectancy:
# 0.8089802514849209

# %%
col = ['red',
 'green',
 'blue',
 'blue',
 'yellow',
 'black',
 'green',
 'red',
 'red',
 'green',
 'blue',
 'yellow',
 'green',
 'blue',
 'yellow',
 'green',
 'blue',
 'blue',
 'red',
 'blue',
 'yellow',
 'blue',
 'blue',
 'yellow',
 'red',
 'yellow',
 'blue',
 'blue',
 'blue',
 'yellow',
 'blue',
 'green',
 'yellow',
 'green',
 'green',
 'blue',
 'yellow',
 'yellow',
 'blue',
 'yellow',
 'blue',
 'blue',
 'blue',
 'green',
 'green',
 'blue',
 'blue',
 'green',
 'blue',
 'green',
 'yellow',
 'blue',
 'blue',
 'yellow',
 'yellow',
 'red',
 'green',
 'green',
 'red',
 'red',
 'red',
 'red',
 'green',
 'red',
 'green',
 'yellow',
 'red',
 'red',
 'blue',
 'red',
 'red',
 'red',
 'red',
 'blue',
 'blue',
 'blue',
 'blue',
 'blue',
 'red',
 'blue',
 'blue',
 'blue',
 'yellow',
 'red',
 'green',
 'blue',
 'blue',
 'red',
 'blue',
 'red',
 'green',
 'black',
 'yellow',
 'blue',
 'blue',
 'green',
 'red',
 'red',
 'yellow',
 'yellow',
 'yellow',
 'red',
 'green',
 'green',
 'yellow',
 'blue',
 'green',
 'blue',
 'blue',
 'red',
 'blue',
 'green',
 'blue',
 'red',
 'green',
 'green',
 'blue',
 'blue',
 'green',
 'red',
 'blue',
 'blue',
 'green',
 'green',
 'red',
 'red',
 'blue',
 'red',
 'blue',
 'yellow',
 'blue',
 'green',
 'blue',
 'green',
 'yellow',
 'yellow',
 'yellow',
 'red',
 'red',
 'red',
 'blue',
 'blue']

# %%
plt.scatter(np.log10(data_2007.gdpPerCapita), data_2007.lifeExpectancy, s=data_2007.population/10**7,c=col,alpha = 0.5)

# %%
plt.scatter(np.log10(data_2007.gdpPerCapita), data_2007.lifeExpectancy, s=data_2007.population/10**7,c=col,alpha = 0.5)

# Add grid() call
plt.grid(True)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("countries.csv")
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
data_2007 = data[data.year == 2007]
data_2007.head()
# Out:
#         country continent  year  lifeExpectancy  population  gdpPerCapita
# 11  Afghanistan      Asia  2007          43.828    31889923    974.580338
# 23      Albania    Europe  2007          76.423     3600523   5937.029526
# 35      Algeria    Africa  2007          72.301    33333216   6223.367465
# 47       Angola    Africa  2007          42.731    12420476   4797.231267
# 59    Argentina  Americas  2007          75.320    40301927  12779.379640

# %%
top10 = data_2007.sort_values('population', ascending=False).head(10)

# %%
x = range(10)
plt.bar(x, top10.population / 10**6)
plt.xticks(x, top10.country, rotation='vertical')
plt.title('10 Most Populous Countries')
plt.ylabel('Population in Millions')
plt.show()

# %% [markdown]
# ### Problem: Find and compare the GDP of the 10 most populous countries in 2007.
# Use plt.hist() and plt.subplots()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
data_2007 = data[data.year == 2007]
top10 = data_2007.sort_values('population', ascending=False).head(10)

# %%
plt.subplot(2, 1, 1)
x = range(10)
plt.bar(x, top10.population / 10**6)
plt.xticks([], [])
plt.title('10 Most Populous Countries')
plt.legend(['Population in Millions'])
plt.subplot(2, 1, 2)
plt.bar(x, top10.gdpPerCapita * top10.population / 10**9)
plt.xticks(x, top10.country, rotation='vertical')
plt.legend(['GDP in Billions'])
plt.show()

# %% [markdown]
# ### Problem: Find the GDP of the 10 most populous countries.

# %% [markdown]
# **Using matplotlib, it is possible to show two sets of bars in a single bar chart.**
#
# It is not the simplest solution, but please feel free to play around with this file for an example of how to create a chart like this.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# As usual, we'll import our countries data.
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
# Find the 10 most populous countries.
data_2007 = data[data.year == 2007]
top10 = data_2007.sort_values('population', ascending=False).head(10)

# %%
import numpy as np # We're going to import np for np.arange().
# np.arange(10) is similar to range(10), and it allows us to shift
# each value in it by the bar width as you can see below.
x = np.arange(10)

# We need to create subplots in order to overlay two bar plots
# with proper axes on the left hand side and the right hand side.
fig, ax1 = plt.subplots()

width = 0.3 # This is the width of each bar in the bar plot.
plt.xticks(x, top10.country, rotation='vertical')
population = ax1.bar(x, top10.population / 10**6, width)
plt.ylabel('Population')

# ax1.twinx() gives us the same x-axis with the y-axis on the right.
ax2 = ax1.twinx()
gdp = ax2.bar(x + width, top10.gdpPerCapita * top10.population / 10**9,
              width, color='orange')
plt.ylabel('GDP')
plt.legend([population, gdp],
           ['Population in Millions', 'GDP in Billions'])
figure = plt.gcf() # get current figure
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data_big = pd.read_csv('obama_too_big.csv', parse_dates=['year_month'])
data = pd.read_csv('obama.csv', parse_dates=['year_month'])

# %%
data.head()
# Out:
#   year_month  survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01             ABC/Post             80.0                15.0
# 1 2009-01-01               AP-GFK             74.0                15.0
# 2 2009-01-01                  CNN             84.0                14.0
# 3 2009-01-01  Democracy Corps (D)             51.0                20.0
# 4 2009-01-01       Diageo/Hotline             64.0                 6.5

# %%
data_big.head()
# Out:
#   year_month survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01      Generated Data             67.0                31.0
# 1 2009-01-01      Harris (Phone)             60.0                29.0
# 2 2009-01-01      Generated Data             65.9                19.1
# 3 2009-01-01      Generated Data             64.6                18.4
# 4 2009-01-01      Generated Data             83.3                11.7

# %%
data.shape
# Out:
# (1530, 4)

# %%
data_big.shape
# Out:
# (65499, 4)

# %%
plt.plot(data_big.year_month, data_big.approve_percent, 'o',
         markersize=2, alpha=0.002)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
sampled = data_big.sample(frac=0.1)
# Use n=10000 to specify a number of samples instead.
plt.plot(sampled.year_month, sampled.approve_percent, 'o',
        markersize=2, alpha=0.02)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('obama.csv', parse_dates=['year_month'])
data.head()
# Out:
#   year_month  survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01             ABC/Post             80.0                15.0
# 1 2009-01-01               AP-GFK             74.0                15.0
# 2 2009-01-01                  CNN             84.0                14.0
# 3 2009-01-01  Democracy Corps (D)             51.0                20.0
# 4 2009-01-01       Diageo/Hotline             64.0                 6.5

# %%
plt.plot(data.year_month, data.approve_percent, 'o', markersize=2,
         alpha=0.3)
plt.show()

# %%
data_mean = data.groupby('year_month').mean()
data_median = data.groupby('year_month').median()
plt.plot(data_mean.index, data_mean.approve_percent, 'red')
plt.plot(data_median.index, data_median.approve_percent, 'green')
plt.legend(['Mean', 'Median'])
plt.plot(data.year_month, data.approve_percent, 'o', markersize=2,
         alpha=0.3)
plt.show()

# %%
data_25 = data.groupby('year_month').quantile(0.25)
data_75 = data.groupby('year_month').quantile(0.75)
plt.plot(data_75.index, data_75.approve_percent, 'green')
plt.plot(data_median.index, data_median.approve_percent, 'red')
plt.plot(data_25.index, data_25.approve_percent, 'blue')
plt.plot(data.year_month, data.approve_percent, 'o', markersize=2,
         alpha=0.3)
plt.legend(['75th Percentile', 'Median', '25th Percentile'])
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('countries.csv')
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
mean_gdp_per_capita = data.groupby(['country']).mean().gdpPerCapita

# %%
top5 = mean_gdp_per_capita.sort_values(ascending=False).head()

# %% [markdown]
# # Is Kuwait really the richest country in the world (on a per-person basis)?

# %%
kuwait = data[data.country == 'Kuwait']
kuwait.head()
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 852  Kuwait      Asia  1952          55.565      160000  108382.35290
# 853  Kuwait      Asia  1957          58.033      212846  113523.13290
# 854  Kuwait      Asia  1962          60.470      358266   95458.11176
# 855  Kuwait      Asia  1967          64.624      575003   80894.88326
# 856  Kuwait      Asia  1972          67.712      841934  109347.86700

# %%
plt.plot(kuwait.year, kuwait.gdpPerCapita)
plt.title('GDP Per Capita in Kuwait')
plt.show()

# %%
plt.subplot(311)
plt.title('GDP Per Capita')
plt.plot(kuwait.year, kuwait.gdpPerCapita)

plt.subplot(312)
plt.title('GDP in Billions')
plt.plot(kuwait.year, kuwait.population*kuwait.gdpPerCapita / 10**9)

plt.subplot(313)
plt.title('Population in Millions')
plt.plot(kuwait.year, kuwait.population / 10**6)

plt.tight_layout()
plt.show()

# %%
plt.plot(kuwait.year, kuwait.population / kuwait.population.iloc[0] * 100)

kuwait_gdp = kuwait.population * kuwait.gdpPerCapita
plt.plot(kuwait.year, kuwait_gdp / kuwait_gdp.iloc[0] * 100)
plt.plot(kuwait.year, kuwait.gdpPerCapita / kuwait.gdpPerCapita.iloc[0] * 100)
plt.title('GDP and Population Growth in Kuwait (first year = 100)')
plt.legend(['Population', 'GDP', 'GDP Per Capita'])
plt.show()

# %%
top5
# Out:
# country
# Kuwait           65332.910472
# Switzerland      27074.334405
# Norway           26747.306554
# United States    26261.151347
# Canada           22410.746340
# Name: gdpPerCapita, dtype: float64

# %%
us = data[data.country == 'United States']

# %%
plt.plot(us.year, us.gdpPerCapita)
plt.plot(kuwait.year, kuwait.gdpPerCapita)
plt.legend(['United States', 'Kuwait'])
plt.show()

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#sns.get_dataset_names()

# %%
tips = sns.load_dataset("tips") 
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips.nunique()   #This gives idea about the unique data in particular column
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %% [markdown]
# # Scatter Plot

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, scatter=True, fit_reg=False, size=6)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# lmplot() → Plot data
# x, y → Input variables, column names in data
# data → Dataframe where each column is a variable and each row is an observation
# scatter → If True, draw a scatter plot
# size → Height of each facet

# %%
sns.lmplot(x='total_bill', y='tip', hue='day', data=tips, scatter=True,
fit_reg=False, size=6)
plt.show()
#hue → Variables that define subsets of the data i.e. third dimension of information
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips, scatter=True,fit_reg=False, size=6,
           palette='ocean', markers=['o', 'x'])
#palette → Seaborn color palette 
#markers → Markers of the scatter plot
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Possible values of pallette :
# Accent, Blues, Greens, Greys, Oranges, Paired, Pastle1, Pastle2, Purples, Reds, Set1, Set2, Set3, Spectral, Vega10, Vega20, Wistia, autumn, binary, bone, cool, coolwarm, copper, cubehelix, flag, gist_earth, gist_gray, gist_heat, gist_rainbow, gray, hot, icefire, inferno, jet, magma, ocean, pink, plasma, prism, rainbow, rocket, seismic, spectral, spring, summer, tab10, tab20, terrain, winter

# %%
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips, scatter=True,fit_reg=False, size=6, 
           palette='summer', markers=['o', 'x'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips,
scatter=True, fit_reg=False)
plt.show()
#col → Variables that define subsets of the data

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", col="time", row="sex",
           data=tips, scatter=True, fit_reg=False, palette='winter');
plt.savefig('scatter.jpg')

#row → Variables that define subsets of the data

# %%
sns.stripplot(x='day', y='total_bill', data=tips, palette='rainbow', size=6) 
plt.show()
#stripplot() → Draw a scatter plot where one variable is categorical #Jitter = False

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, palette='spring', size=6)
plt.show()
#swarmplot() → Draw a categorical scatter plot with non-overlapping points

# %%
sns.countplot(x='sex', data=tips, palette='Oranges')
plt.show()
#countplot() → Show the counts of observations in each categorical bin using bars.

# %%
sns.countplot(x='sex', hue='time', data=tips, palette='Oranges')
#countplot() → Show the counts of observations in each categorical bin using bars.

# %%
sns.distplot(tips['total_bill'])
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip',data = tips, size=8)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x='total_bill', y='tip',data = tips, size=8,kind = 'hex')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x=tips["total_bill"])

# %%
a = sns.boxplot(x="day", y="total_bill", data=tips)

# %%
a = sns.boxplot(x="day", y="total_bill", data=tips, whis = False)

# %%
sns.pairplot(tips,hue='time')

# %%
import pandas as pd
auto = pd.read_csv("auto-mpg.csv")

# %%
from matplotlib import pyplot as plt

# %%
auto.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang   blue
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d   blue
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc    red
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada   blue
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000  green
#
#    size
# 0  15.0
# 1  20.0
# 2  10.0
# 3  15.0
# 4  10.0

# %%
hp = auto['hp']
mpg = auto['mpg']

# %%
# Generate a 2-D histogram
plt.hist2d(hp, mpg, bins=(20,20), 
           range=((40,235), (8, 48)))

# Add a color bar to the histogram
plt.colorbar()

# Add labels, title, and display the plot
plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hist2d() plot')
plt.show()

# %%
# Generate a 2d histogram with hexagonal bins
plt.hexbin(hp, mpg, gridsize=(15,12), 
           extent=(40,235,8, 48))
           
# Add a color bar to the histogram
plt.colorbar()

# Add labels, title, and display the plot
plt.xlabel('Horse power [hp]')
plt.ylabel('Miles per gallon [mpg]')
plt.title('hexbin() plot')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips,hue='sex',palette='Set1')
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')
plt.show()

# %%
sns.residplot(x='total_bill',y='tip',data=tips,color='indianred')
plt.show()

# %%
# Generate a scatter plot of 'weight' and 'mpg' using red circles
plt.scatter(auto['weight'], auto['mpg'], label='data', color='red', marker='o')

# Plot in blue a linear regression of order 1 between 'weight' and 'mpg'
sns.regplot(x='weight', y='mpg', data=auto, scatter=None, color='blue', label='order 1')

# Plot in green a linear regression of order 2 between 'weight' and 'mpg'
sns.regplot(x='weight', y='mpg', data=auto, scatter=None, order=2, color='green', label='order 2')

# Add a legend and display the plot
plt.legend(loc='upper right')
plt.show()

# %%
sns.swarmplot(x='sex',y='tip',data=tips)
plt.show()

# %%
sns.violinplot(x='day',y='tip',data=tips,inner=None,color='lightgray')
sns.stripplot(x='day',y='tip',data=tips,size=4,jitter=True)
plt.show()

# %%
sns.stripplot(x='day',y='tip',data=tips,size=4,jitter=False)

# %%
sns.stripplot(x='day',y='tip',data=tips,size=4,jitter=True)

# %%
# Make a strip plot of 'hp' grouped by 'cyl'
plt.subplot(2,1,1)
sns.stripplot(x='cyl', y='hp', data=auto)

# Make the strip plot again using jitter and a smaller point size
plt.subplot(2,1,2)
sns.stripplot(x='cyl', y='hp', data=auto, jitter=True, size=3)

# Display the plot
plt.show()

# %%
# Generate a swarm plot of 'hp' grouped horizontally by 'cyl'  
plt.subplot(2,1,1)
sns.swarmplot(x='cyl', y='hp', data=auto)

# Generate a swarm plot of 'hp' grouped vertically by 'cyl' with a hue of 'origin'
plt.subplot(2,1,2)
sns.swarmplot(x='hp', y='cyl', data=auto, hue='origin', orient='h')

# Display the plot
plt.show()

# %%
# Generate a violin plot of 'hp' grouped horizontally by 'cyl'
plt.subplot(2,1,1)
sns.violinplot(x='cyl', y='hp', data=auto)

# Generate the same violin plot again with a color of 'lightgray' and without inner annotations
plt.subplot(2,1,2)
sns.violinplot(x='cyl', y='hp', data=auto, inner=None, color='lightgray')

# Overlay a strip plot on the violin plot
sns.stripplot(x='cyl', y='hp', data=auto, jitter=True, size=1.5)

# Display the plot
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hexbin')
plt.show()

# %%
import seaborn as sns
sns.pairplot(auto,diag_kind='kde')
plt.show()

# %%
sns.pairplot(tips,hue='sex')
plt.show()

# %%
auto.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang   blue
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d   blue
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc    red
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada   blue
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000  green
#
#    size
# 0  15.0
# 1  20.0
# 2  10.0
# 3  15.0
# 4  10.0

# %%
#Correlation matrix
#Pairwise correlations between numeric variables
auto.corr()
# Out:
#              mpg       cyl     displ        hp    weight     accel        yr  \
# mpg     1.000000 -0.777618 -0.805127 -0.778427 -0.832244  0.423329  0.580541
# cyl    -0.777618  1.000000  0.950823  0.842983  0.897527 -0.504683 -0.345647
# displ  -0.805127  0.950823  1.000000  0.897257  0.932994 -0.543800 -0.369855
# hp     -0.778427  0.842983  0.897257  1.000000  0.864538 -0.689196 -0.416361
# weight -0.832244  0.897527  0.932994  0.864538  1.000000 -0.416839 -0.309120
# accel   0.423329 -0.504683 -0.543800 -0.689196 -0.416839  1.000000  0.290316
# yr      0.580541 -0.345647 -0.369855 -0.416361 -0.309120  0.290316  1.000000
# size   -0.777618  1.000000  0.950823  0.842983  0.897527 -0.504683 -0.345647
#
#             size
# mpg    -0.777618
# cyl     1.000000
# displ   0.950823
# hp      0.842983
# weight  0.897527
# accel  -0.504683
# yr     -0.345647
# size    1.000000

# %%
tips.cov()
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
sns.heatmap(auto.corr(),cmap="BuGn")
plt.show()

# %%
# import all modules
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read in the DataFrame
df = pd.read_csv('C:\\Users\\Sayan\\OneDrive\\Documents\\Workspace\\FINAL_PYTHON\\datasets\\schoolimprovement2010grants.csv')

# %%
df
# Out:
#      Unnamed: 0                                       School Name  \
# 0             0                 HOGARTH KINGEEKUK MEMORIAL SCHOOL
# 1             1                                   AKIACHAK SCHOOL
# 2             2                                    GAMBELL SCHOOL
# 3             3                              BURCHELL HIGH SCHOOL
# 4             4                                      AKIAK SCHOOL
# 5             5                                    MIDVALLEY HIGH
# 6             6                                   TULUKSAK SCHOOL
# 7             7                       CAPITOL HEIGHTS JR HIGH SCH
# 8             8                             LOWNDES CO MIDDLE SCH
# 9             9                                CENTRAL MIDDLE SCH
# 10           10                           BELLINGRATH JR HIGH SCH
# 11           11                             HAYNEVILLE MIDDLE SCH
# 12           12                              SOUTHLAWN MIDDLE SCH
# 13           13                           CONTINUOUS LEARNING CTR
# 14           14                           JACKSON-STEELE ELEM SCH
# 15           15                               MCINTYRE MIDDLE SCH
# 16           16                               JOHN ESSEX HIGH SCH
# 17           17                                  CALHOUN HIGH SCH
# 18           18                             OSCEOLA MIDDLE SCHOOL
# 19           19                                  HALL HIGH SCHOOL
# 20           20                           ROSE CITY MIDDLE SCHOOL
# 21           21                          TRUSTY ELEMENTARY SCHOOL
# 22           22                             J.A. FAIR HIGH SCHOOL
# 23           23                               OSCEOLA HIGH SCHOOL
# 24           24                          CLOVERDALE MIDDLE SCHOOL
# 25           25                         GADSDEN ELEMENTARY SCHOOL
# 26           26                           EAST VALLEY HIGH SCHOOL
# 27           27                          CRITTENTON YOUTH ACADEMY
# 28           28                              ALCHESAY HIGH SCHOOL
# 29           29                            SAN CARLOS HIGH SCHOOL
# ..          ...                                               ...
# 727         801                          WASHINGTON MIDDLE SCHOOL
# 728         802  FOSTER & WILLIAMS HIGH SCHOOL OF THE VISUAL ARTS
# 729         803                                       DUBOIS HIGH
# 730         804                                       CUSTER HIGH
# 731         805                     JAMES MADISON ACADEMIC CAMPUS
# 732         806                                      VINCENT HIGH
# 733         807                                     BAY VIEW HIGH
# 734         808       DOWNTOWN INSTITUTE OF ARTS & LETTERS (DIAL)
# 735         809                               SOUTH DIVISION HIGH
# 736         810         MILWAUKEE AFRICAN AMERICAN IMMERSION HIGH
# 737         811                WHS LAW EDUCATION & PUBLIC SERVICE
# 738         812                           BRADLEY TECHNOLOGY HIGH
# 739         813                                       HAMLIN PK-8
# 740         814                             RIVERSIDE HIGH SCHOOL
# 741         815                DODDRIDGE COUNTY ELEMENTARY SCHOOL
# 742         816                            MOUNT VIEW HIGH SCHOOL
# 743         817                            WEST HAMLIN ELEMENTARY
# 744         818                          MALDEN ELEMENTARY SCHOOL
# 745         819                   MARTINSBURG NORTH MIDDLE SCHOOL
# 746         820                         SANDY RIVER MIDDLE SCHOOL
# 747         821                   STONEWALL JACKSON MIDDLE SCHOOL
# 748         822                           EAST BANK MIDDLE SCHOOL
# 749         823                        FRANKLIN ELEMENTARY CENTER
# 750         824                               GUYAN VALLEY MIDDLE
# 751         825                         CEDAR GROVE MIDDLE SCHOOL
# 752         826                            MOUNT HOPE HIGH SCHOOL
# 753         827                           GEARY ELEMENTARY SCHOOL
# 754         828                               TRIUMPH HIGH SCHOOL
# 755         829                     HEM JUNIOR/SENIOR HIGH SCHOOL
# 756         830                             ROOSEVELT HIGH SCHOOL
#
#                   City State                                  District Name  \
# 0             SAVOONGA    AK                  BERING STRAIT SCHOOL DISTRICT
# 1             AKIACHAK    AK                         YUPIIT SCHOOL DISTRICT
# 2              GAMBELL    AK                  BERING STRAIT SCHOOL DISTRICT
# 3              WASILLA    AK      MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT
# 4                AKIAK    AK                         YUPIIT SCHOOL DISTRICT
# 5              WASILLA    AK      MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT
# 6             TULUKSAK    AK                         YUPIIT SCHOOL DISTRICT
# 7           MONTGOMERY    AL                              MONTGOMERY COUNTY
# 8         FORT DEPOSIT    AL                                 LOWNDES COUNTY
# 9             ROCKFORD    AL                                   COOSA COUNTY
# 10          MONTGOMERY    AL                              MONTGOMERY COUNTY
# 11          HAYNEVILLE    AL                                 LOWNDES COUNTY
# 12          MONTGOMERY    AL                              MONTGOMERY COUNTY
# 13              MOBILE    AL                                  MOBILE COUNTY
# 14          HAYNEVILLE    AL                                 LOWNDES COUNTY
# 15          MONTGOMERY    AL                              MONTGOMERY COUNTY
# 16           DEMOPOLIS    AL                                 MARENGO COUNTY
# 17         LETOHATCHEE    AL                                 LOWNDES COUNTY
# 18             OSCEOLA    AR                        OSCEOLA SCHOOL DISTRICT
# 19         LITTLE ROCK    AR                    LITTLE ROCK SCHOOL DISTRICT
# 20   NORTH LITTLE ROCK    AR                 N. LITTLE ROCK SCHOOL DISTRICT
# 21          FORT SMITH    AR                     FORT SMITH SCHOOL DISTRICT
# 22         LITTLE ROCK    AR                    LITTLE ROCK SCHOOL DISTRICT
# 23             OSCEOLA    AR                        OSCEOLA SCHOOL DISTRICT
# 24         LITTLE ROCK    AR                    LITTLE ROCK SCHOOL DISTRICT
# 25             GADSDEN    AZ                    GADSDEN ELEMENTARY DISTRICT
# 26                MESA    AZ                         LEGACY EDUCATION GROUP
# 27             PHOENIX    AZ  FLORENCE CRITTENTON SERVICES OF ARIZONA  INC.
# 28          WHITERIVER    AZ                    WHITERIVER UNIFIED DISTRICT
# 29          SAN CARLOS    AZ                    SAN CARLOS UNIFIED DISTRICT
# ..                 ...   ...                                            ...
# 727             YAKIMA    WA                         YAKIMA SCHOOL DISTRICT
# 728          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 729          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 730          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 731          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 732          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 733          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 734          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 735          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 736          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 737          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 738          MILWAUKEE    WI                      MILWAUKEE SCHOOL DISTRICT
# 739             HAMLIN    WV                         LINCOLN COUNTY SCHOOLS
# 740              BELLE    WV                         KANAWHA COUNTY SCHOOLS
# 741         WEST UNION    WV                       DODDRIDGE COUNTY SCHOOLS
# 742              WELCH    WV                        MCDOWELL COUNTY SCHOOLS
# 743        WEST HAMLIN    WV                         LINCOLN COUNTY SCHOOLS
# 744         CHARLESTON    WV                         KANAWHA COUNTY SCHOOLS
# 745        MARTINSBURG    WV                        BERKELEY COUNTY SCHOOLS
# 746           AVONDALE    WV                        MCDOWELL COUNTY SCHOOLS
# 747         CHARLESTON    WV                         KANAWHA COUNTY SCHOOLS
# 748          EAST BANK    WV                         KANAWHA COUNTY SCHOOLS
# 749        PARKERSBURG    WV                            WOOD COUNTY SCHOOLS
# 750         BRANCHLAND    WV                         LINCOLN COUNTY SCHOOLS
# 751        CEDAR GROVE    WV                         KANAWHA COUNTY SCHOOLS
# 752         MOUNT HOPE    WV                         FAYETTE COUNTY SCHOOLS
# 753          LEFT HAND    WV                           ROANE COUNTY SCHOOLS
# 754           CHEYENNE    WY              LARAMIE COUNTY SCHOOL DISTRICT #1
# 755              HANNA    WY               CARBON COUNTY SCHOOL DISTRICT #2
# 756             CASPER    WY              NATRONA COUNTY SCHOOL DISTRICT #1
#
#      Model Selected  Award_Amount   Region
# 0    Transformation        471014     West
# 1    Transformation        520579     West
# 2    Transformation        449592     West
# 3    Transformation        641184     West
# 4    Transformation        399686     West
# 5           Restart        697703     West
# 6    Transformation        427658     West
# 7    Transformation        110544    South
# 8    Transformation         12973    South
# 9    Transformation        199828    South
# 10   Transformation        165903    South
# 11   Transformation        121657    South
# 12   Transformation        914557    South
# 13   Transformation        198953    South
# 14   Transformation        118394    South
# 15   Transformation        143238    South
# 16   Transformation        151116    South
# 17   Transformation        163619    South
# 18   Transformation        665000    South
# 19   Transformation        198728    South
# 20   Transformation        991451    South
# 21   Transformation        990135    South
# 22   Transformation        197012    South
# 23   Transformation        695000    South
# 24   Transformation        198783    South
# 25   Transformation        847003     West
# 26       Turnaround        381512     West
# 27       Turnaround        915959     West
# 28   Transformation        812195     West
# 29   Transformation        928654     West
# ..              ...           ...      ...
# 727  Transformation        115268     West
# 728         Closure         10000  Midwest
# 729         Closure         10000  Midwest
# 730         Restart        650093  Midwest
# 731  Transformation        749320  Midwest
# 732  Transformation        928024  Midwest
# 733  Transformation        134909  Midwest
# 734         Closure         10000  Midwest
# 735  Transformation        124643  Midwest
# 736         Restart        567905  Midwest
# 737         Closure         10000  Midwest
# 738  Transformation         10000  Midwest
# 739  Transformation        258600    South
# 740  Transformation        481900    South
# 741  Transformation        464200    South
# 742  Transformation        450000    South
# 743  Transformation        156660    South
# 744  Transformation        217598    South
# 745  Transformation        461690    South
# 746  Transformation        370000    South
# 747  Transformation        241211    South
# 748  Transformation        314618    South
# 749  Transformation        389906    South
# 750  Transformation        341250    South
# 751  Transformation        211271    South
# 752  Transformation        342189    South
# 753  Transformation        260000    South
# 754  Transformation        297300     West
# 755  Transformation        274000     West
# 756  Transformation        431382     West
#
# [757 rows x 8 columns]

# %%
# Display a Seaborn distplot
sns.distplot(df['Award_Amount'])
plt.show()

# %%
# Create a distplot
sns.distplot(df['Award_Amount'],
             kde=False,
             bins=20)

# Display a plot
plt.show()

# %%
# Create a distplot of the Award Amount
sns.distplot(df['Award_Amount'],
             hist=False,
             rug=True,
             kde_kws={'shade':True})

# Plot the results
plt.show()

# %%
# Read in the DataFrame
df = pd.read_csv('C:\\Users\\Sayan\\OneDrive\\Documents\\Workspace\\FINAL_PYTHON\\datasets\\insurance_premiums.csv')

# %%
df
# Out:
#                    State  fatal_collisions  fatal_collisions_speeding  \
# 0                Alabama              18.8                         39
# 1                 Alaska              18.1                         41
# 2                Arizona              18.6                         35
# 3               Arkansas              22.4                         18
# 4             California              12.0                         35
# 5               Colorado              13.6                         37
# 6            Connecticut              10.8                         46
# 7               Delaware              16.2                         38
# 8   District of Columbia               5.9                         34
# 9                Florida              17.9                         21
# 10               Georgia              15.6                         19
# 11                Hawaii              17.5                         54
# 12                 Idaho              15.3                         36
# 13              Illinois              12.8                         36
# 14               Indiana              14.5                         25
# 15                  Iowa              15.7                         17
# 16                Kansas              17.8                         27
# 17              Kentucky              21.4                         19
# 18             Louisiana              20.5                         35
# 19                 Maine              15.1                         38
# 20              Maryland              12.5                         34
# 21         Massachusetts               8.2                         23
# 22              Michigan              14.1                         24
# 23             Minnesota               9.6                         23
# 24           Mississippi              17.6                         15
# 25              Missouri              16.1                         43
# 26               Montana              21.4                         39
# 27              Nebraska              14.9                         13
# 28                Nevada              14.7                         37
# 29         New Hampshire              11.6                         35
# 30            New Jersey              11.2                         16
# 31            New Mexico              18.4                         19
# 32              New York              12.3                         32
# 33        North Carolina              16.8                         39
# 34          North Dakota              23.9                         23
# 35                  Ohio              14.1                         28
# 36              Oklahoma              19.9                         32
# 37                Oregon              12.8                         33
# 38          Pennsylvania              18.2                         50
# 39          Rhode Island              11.1                         34
# 40        South Carolina              23.9                         38
# 41          South Dakota              19.4                         31
# 42             Tennessee              19.5                         21
# 43                 Texas              19.4                         40
# 44                  Utah              11.3                         43
# 45               Vermont              13.6                         30
# 46              Virginia              12.7                         19
# 47            Washington              10.6                         42
# 48         West Virginia              23.8                         34
# 49             Wisconsin              13.8                         36
# 50               Wyoming              17.4                         42
#
#     fatal_collisions_alc  fatal_collisions_not_distracted  \
# 0                     30                               96
# 1                     25                               90
# 2                     28                               84
# 3                     26                               94
# 4                     28                               91
# 5                     28                               79
# 6                     36                               87
# 7                     30                               87
# 8                     27                              100
# 9                     29                               92
# 10                    25                               95
# 11                    41                               82
# 12                    29                               85
# 13                    34                               94
# 14                    29                               95
# 15                    25                               97
# 16                    24                               77
# 17                    23                               78
# 18                    33                               73
# 19                    30                               87
# 20                    32                               71
# 21                    35                               87
# 22                    28                               95
# 23                    29                               88
# 24                    31                               10
# 25                    34                               92
# 26                    44                               84
# 27                    35                               93
# 28                    32                               95
# 29                    30                               87
# 30                    28                               86
# 31                    27                               67
# 32                    29                               88
# 33                    31                               94
# 34                    42                               99
# 35                    34                               99
# 36                    29                               92
# 37                    26                               67
# 38                    31                               96
# 39                    38                               92
# 40                    41                               96
# 41                    33                               98
# 42                    29                               82
# 43                    38                               91
# 44                    16                               88
# 45                    30                               96
# 46                    27                               87
# 47                    33                               82
# 48                    28                               97
# 49                    33                               39
# 50                    32                               81
#
#     fatal_collisions_no_hist  premiums  insurance_losses     Region
# 0                         80    784.55            145.08      South
# 1                         94   1053.48            133.93       West
# 2                         96    899.47            110.35       West
# 3                         95    827.34            142.39      South
# 4                         89    878.41            165.63       West
# 5                         95    835.50            139.91       West
# 6                         82   1068.73            167.02  Northeast
# 7                         99   1137.87            151.48      South
# 8                        100   1273.89            136.05      South
# 9                         94   1160.13            144.18      South
# 10                        93    913.15            142.80      South
# 11                        87    861.18            120.92       West
# 12                        98    641.96             82.75       West
# 13                        96    803.11            139.15    Midwest
# 14                        95    710.46            108.92    Midwest
# 15                        87    649.06            114.47    Midwest
# 16                        85    780.45            133.80    Midwest
# 17                        76    872.51            137.13      South
# 18                        98   1281.55            194.78      South
# 19                        84    661.88             96.57  Northeast
# 20                        99   1048.78            192.70      South
# 21                        80   1011.14            135.63  Northeast
# 22                        77   1110.61            152.26    Midwest
# 23                        88    777.18            133.35    Midwest
# 24                       100    896.07            155.77      South
# 25                        84    790.32            144.45    Midwest
# 26                        85    816.21             85.15       West
# 27                        90    732.28            114.82    Midwest
# 28                        99   1029.87            138.71       West
# 29                        83    746.54            120.21  Northeast
# 30                        78   1301.52            159.85  Northeast
# 31                        98    869.85            120.75       West
# 32                        80   1234.31            150.01  Northeast
# 33                        81    708.24            127.82      South
# 34                        86    688.75            109.72    Midwest
# 35                        82    697.73            133.52    Midwest
# 36                        94    881.51            178.86      South
# 37                        90    804.71            104.61       West
# 38                        88    905.99            153.86  Northeast
# 39                        79   1148.99            148.58  Northeast
# 40                        81    858.97            116.29      South
# 41                        86    669.31             96.87    Midwest
# 42                        81    767.91            155.57      South
# 43                        87   1004.75            156.83      South
# 44                        96    809.38            109.48       West
# 45                        95    716.20            109.61  Northeast
# 46                        88    768.95            153.72      South
# 47                        86    890.03            111.62       West
# 48                        87    992.61            152.56      South
# 49                        84    670.31            106.62    Midwest
# 50                        90    791.14            122.04       West

# %%
#regplot and lmplot difference

# %%
sns.regplot(data=df,
            x="insurance_losses",
            y="premiums")

# Display the plot
plt.show()

# %%
sns.lmplot(data=df,
           x="insurance_losses",
           y="premiums")

# Display the second plot
plt.show()

# %%
# Create a regression plot using hue
sns.lmplot(data=df,
           x="insurance_losses",
           y="premiums",
           hue="Region")

#Show the results
plt.show()

# %%
# Create a regression plot with multiple rows
sns.lmplot(data=df,
           x="insurance_losses",
           y="premiums",
           col="Region")

# Show the plot
plt.show()

# %%
# Read in the DataFrame
df = pd.read_csv('C:\\Users\\Sayan\\OneDrive\\Documents\\Workspace\\FINAL_PYTHON\\datasets\\FY18_4050_FMRs.csv')

# %%
# Plot the pandas histogram
df['fmr_2'].plot.hist()
plt.show()
plt.clf()

# Set the default seaborn style
sns.set()

# Plot the pandas histogram again
df['fmr_2'].plot.hist()
plt.show()
plt.clf()

# %%
# Plot with a dark style 
sns.set_style('dark')
sns.distplot(df['fmr_2'])
plt.show()

# Clear the figure
plt.clf()

# %%
# Plot with a whitegrid style
sns.set_style('whitegrid')
sns.distplot(df['fmr_2'])
plt.show()

# Clear the figure
plt.clf()

# %%
# Set the style to white
sns.set_style('white')

# Create a regression plot
sns.lmplot(data=df,
           x='pop2010',
           y='fmr_2')

# Remove the spines
#sns.despine()

# Show the plot and clear the figure
plt.show()
plt.clf()

# %%
# Set style, enable color code, and create a magenta distplot
sns.set(color_codes=True)
sns.distplot(df['fmr_3'], color='m')

# Show the plot
plt.show()

# %%
# Loop through differences between bright and colorblind palettes
for p in ['bright', 'colorblind']:
    sns.set_palette(p)
    sns.distplot(df['fmr_3'])
    plt.show()
    
    # Clear the plots
    plt.clf()

# %%
# Create the Purples palette
sns.palplot(sns.color_palette("Purples", 8))
plt.show()

# %%
# Create the husl palette
sns.palplot(sns.color_palette("husl", 10))
plt.show()

# %%
# Create the coolwarm palette
sns.palplot(sns.color_palette("coolwarm", 6))
plt.show()

# %%
# Create a figure and axes
fig, ax = plt.subplots()

# Plot the distribution of data
sns.distplot(df['fmr_3'], ax=ax)

# Create a more descriptive x axis label
ax.set(xlabel="3 Bedroom Fair Market Rent")

# Show the plot
plt.show()

# %%
# Create a figure and axes
fig, ax = plt.subplots()

# Plot the distribution of 1 bedroom rents
sns.distplot(df['fmr_1'], ax=ax)

# Modify the properties of the plot
ax.set(xlabel="1 Bedroom Fair Market Rent",
       xlim=(100,1500),
       title="US Rent")

# Display the plot
plt.show()

# %%
# Create a plot with 1 row and 2 columns that share the y axis label
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharey=True)

# Plot the distribution of 1 bedroom apartments on ax0
sns.distplot(df['fmr_1'], ax=ax0)
ax0.set(xlabel="1 Bedroom Fair Market Rent", xlim=(100,1500))

# Plot the distribution of 2 bedroom apartments on ax1
sns.distplot(df['fmr_2'], ax=ax1)
ax1.set(xlabel="2 Bedroom Fair Market Rent", xlim=(100,1500))

# Display the plot
plt.show()

# %%
# Read in the DataFrame
df = pd.read_csv('C:\\Users\\Sayan\\OneDrive\\Documents\\Workspace\\FINAL_PYTHON\\datasets\\schoolimprovement2010grants.csv')

# %%
# Create the stripplot
sns.stripplot(data=df,
              x='Award_Amount',
              y='Model Selected',
              jitter=True)

plt.show()

# %%
# Create and display a swarmplot with hue set to the Region
sns.swarmplot(data=df,
              x='Award_Amount',
              y='Model Selected',
              hue='Region')

plt.show()

# %%
# Create a boxplot
sns.boxplot(data=df,
            x='Award_Amount',
            y='Model Selected')

plt.show()
plt.clf()

# %%
# Create a violinplot with the husl palette
sns.violinplot(data=df,
               x='Award_Amount',
               y='Model Selected',
               palette='husl')

plt.show()
plt.clf()

# %%
# Create a lvplot with the Paired palette and the Region column as the hue
sns.lvplot(data=df,
           x='Award_Amount',
           y='Model Selected',
           palette='Paired',
           hue='Region')

plt.show()
plt.clf()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:2612: UserWarning: The `lvplot` function has been renamed to `boxenplot`. The original name will be removed in a future release. Please update your code.
#   warnings.warn(msg)
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# Show a countplot with the number of models used with each region a different color
sns.countplot(data=df,
              y="Model Selected",
              hue="Region")

plt.show()
plt.clf()

# %%
# Create a pointplot and include the capsize in order to show bars on the confidence interval
sns.pointplot(data=df,
              y='Award_Amount',
              x='Model Selected',
              capsize=.1,
             hue='Region')

plt.show()
plt.clf()

# %%
# Create a pointplot and include the capsize in order to show bars on the confidence interval
sns.pointplot(data=df,
              y='Award_Amount',
              x='Model Selected',
              capsize=.1)

plt.show()
plt.clf()

# %%
# Create a barplot with each Region shown as a different color
sns.barplot(data=df,
            y='Award_Amount',
            x='Model Selected',
            hue='Region')

plt.show()
plt.clf()

# %%
# Read in the DataFrame
df = pd.read_csv('C:\\Users\\Sayan\\OneDrive\\Documents\\Workspace\\FINAL_PYTHON\\datasets\\college_datav3.csv')

# %%
df
# Out:
#                                                  INSTNM     OPEID  REGION  \
# 0                              Alabama A & M University    100200       5
# 1                   University of Alabama at Birmingham    105200       5
# 2                                    Amridge University   2503400       5
# 3                   University of Alabama in Huntsville    105500       5
# 4                              Alabama State University    100500       5
# 5                             The University of Alabama    105100       5
# 6                     Central Alabama Community College    100700       5
# 7                               Athens State University    100800       5
# 8                       Auburn University at Montgomery    831000       5
# 9                                     Auburn University    100900       5
# 10                          Birmingham Southern College    101200       5
# 11               Chattahoochee Valley Community College   1218200       5
# 12                            Concordia College Alabama   1055400       5
# 13                          South University-Montgomery   1303906       5
# 14                   Enterprise State Community College    101500       5
# 15             James H Faulkner State Community College    106000       5
# 16                                  Faulkner University    100300       5
# 17                      Gadsden State Community College    101700       5
# 18                 New Beginning College of Cosmetology   4187200       5
# 19      George C Wallace State Community College-Dothan    101800       5
# 20    George C Wallace State Community College-Hance...    787100       5
# 21       George C Wallace State Community College-Selma    569900       5
# 22                        Herzing University-Birmingham    962107       5
# 23                                   Huntingdon College    101900       5
# 24                        Heritage Christian University   2199700       5
# 25      J F Drake State Community and Technical College    526000       5
# 26                        Jacksonville State University    102000       5
# 27                    Jefferson Davis Community College    102100       5
# 28                    Jefferson State Community College    102200       5
# 29               John C Calhoun State Community College    101300       5
# ...                                                 ...       ...     ...
# 6672  Cambridge Institute of Allied Health & Technology   4083401       5
# 6673                       Professional Hands Institute   4143101       5
# 6674                                 Utah County Campus   4145501       7
# 6675                       L'esprit Academy - Royal Oak   4158401       3
# 6676     National Career Institute - Jersey City Branch   4154901       2
# 6677   Somerset County Technology Center - Bedford Site   4149801       2
# 6678                     Strayer University-Cobb Campus    145940       5
# 6679                   Strayer University-Morrow Campus    145946       5
# 6680                  Strayer University-Roswell Campus    145952       5
# 6681             Strayer University-Douglasville Campus    145959       5
# 6682                 Strayer University-Lithonia Campus    145965       5
# 6683                 Strayer University-Savannah Campus    145971       5
# 6684                  Strayer University-Augusta Campus    145972       5
# 6685                 Strayer University-Columbia Campus    145945       5
# 6686               Strayer University-Charleston Campus    145954       5
# 6687                          Strayer University-Irving    145990       6
# 6688               Strayer University-Northwest Houston    145994       6
# 6689                      Strayer University-Cedar Hill  10145900       6
# 6690                    Strayer University-North Dallas  10145901       6
# 6691                     Strayer University-San Antonio  10145908       6
# 6692                        Strayer University-Stafford  10145909       6
# 6693                                     Unitek College   4169701       8
# 6694        Relay Graduate School of Education - Newark   4208601       2
# 6695   Relay Graduate School of Education - New Orleans   4208602       5
# 6696                           WestMed College - Merced   4088301       8
# 6697          SAE Institute of Technology San Francisco   4205801       8
# 6698                  Rasmussen College - Overland Park    869423       4
# 6699  National Personal Training Institute of Cleveland   4220901       3
# 6700  Bay Area Medical Academy - San Jose Satellite ...   4223701       8
# 6701                        High Desert Medical College   4228101       8
#
#       SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL  \
# 0           850.0   0.7249    0.8159      0.653841   4380.0     7017.0
# 1          1147.0   0.3505    0.5218      0.604275  10331.0    10221.0
# 2             NaN   0.7455    0.8781           NaN     98.0     3217.0
# 3          1221.0   0.3179    0.4589      0.811971   5220.0     9514.0
# 4           844.0   0.7567    0.7692      0.463858   4348.0     7940.0
# 5          1181.0   0.2009    0.4059      0.535867  15318.0     9710.0
# 6             NaN   0.5554    0.3574           NaN   1577.0     5671.0
# 7             NaN   0.4233    0.6512           NaN   2662.0     7921.0
# 8           990.0   0.4373    0.5584      0.787089   4098.0     7588.0
# 9          1218.0   0.1631    0.3470      0.776605  18326.0     9738.0
# 10         1167.0   0.1992    0.4633      0.530579   1395.0     7078.0
# 11            NaN   0.6050    0.3058           NaN   1748.0     5906.0
# 12            NaN   0.9048    0.9249      0.403397    532.0     5605.0
# 13            NaN   0.6922    0.7304           NaN    207.0     4446.0
# 14            NaN   0.4928    0.2128           NaN   1590.0     6300.0
# 15            NaN   0.4634    0.5107           NaN   2775.0     5988.0
# 16          985.0   0.5596    0.7105      0.573014    612.0     5973.0
# 17            NaN   0.5604    0.0000           NaN   4787.0     6046.0
# 18            NaN   0.6707    0.5749           NaN      NaN        NaN
# 19            NaN   0.5398    0.0000           NaN   3612.0     5665.0
# 20            NaN   0.4982    0.3915           NaN   4696.0     5959.0
# 21            NaN   0.7398    0.0000           NaN   1445.0     5232.0
# 22            NaN   0.5927    0.7219      0.926706    534.0     5206.0
# 23          992.0   0.4207    0.6862      0.576944    657.0     5911.0
# 24          848.0   0.5806    0.3226      0.700000     95.0     3439.0
# 25            NaN   0.6930    0.0000           NaN    543.0     5499.0
# 26         1062.0   0.4308    0.6746      0.666451   6491.0     6795.0
# 27            NaN   0.5516    0.0000           NaN   1129.0     5724.0
# 28            NaN   0.3329    0.2156           NaN   5652.0     6148.0
# 29            NaN   0.3909    0.2877           NaN   7719.0     6156.0
# ...           ...      ...       ...           ...      ...        ...
# 6672          NaN      NaN       NaN           NaN      NaN        NaN
# 6673          NaN      NaN       NaN           NaN      NaN        NaN
# 6674          NaN      NaN       NaN           NaN      NaN        NaN
# 6675          NaN      NaN       NaN           NaN      NaN        NaN
# 6676          NaN      NaN       NaN           NaN      NaN        NaN
# 6677          NaN      NaN       NaN           NaN      NaN        NaN
# 6678          NaN      NaN       NaN           NaN      NaN        NaN
# 6679          NaN      NaN       NaN           NaN      NaN        NaN
# 6680          NaN      NaN       NaN           NaN      NaN        NaN
# 6681          NaN      NaN       NaN           NaN      NaN        NaN
# 6682          NaN      NaN       NaN           NaN      NaN        NaN
# 6683          NaN      NaN       NaN           NaN      NaN        NaN
# 6684          NaN      NaN       NaN           NaN      NaN        NaN
# 6685          NaN      NaN       NaN           NaN      NaN        NaN
# 6686          NaN      NaN       NaN           NaN      NaN        NaN
# 6687          NaN      NaN       NaN           NaN      NaN        NaN
# 6688          NaN      NaN       NaN           NaN      NaN        NaN
# 6689          NaN      NaN       NaN           NaN      NaN        NaN
# 6690          NaN      NaN       NaN           NaN      NaN        NaN
# 6691          NaN      NaN       NaN           NaN      NaN        NaN
# 6692          NaN      NaN       NaN           NaN      NaN        NaN
# 6693          NaN      NaN       NaN           NaN      NaN        NaN
# 6694          NaN      NaN       NaN           NaN      NaN        NaN
# 6695          NaN      NaN       NaN           NaN      NaN        NaN
# 6696          NaN      NaN       NaN           NaN      NaN        NaN
# 6697          NaN      NaN       NaN           NaN      NaN        NaN
# 6698          NaN      NaN       NaN           NaN      NaN        NaN
# 6699          NaN      NaN       NaN           NaN      NaN        NaN
# 6700          NaN      NaN       NaN           NaN      NaN        NaN
# 6701          NaN      NaN       NaN           NaN      NaN        NaN
#
#        COMPL_RPY_5YR_RT  ... CONTROL WOMENONLY  MENONLY  LOCALE  Tuition  \
# 0           0.477631579  ...       1       0.0      0.0    12.0  13435.0
# 1           0.673230442  ...       1       0.0      0.0    12.0  16023.0
# 2           0.636363636  ...       2       0.0      0.0    12.0   8862.0
# 3           0.762222222  ...       1       0.0      0.0    12.0  18661.0
# 4            0.43006993  ...       1       0.0      0.0    12.0   7400.0
# 5            0.75203252  ...       1       0.0      0.0    13.0  20575.0
# 6           0.543478261  ...       1       0.0      0.0    32.0   5958.0
# 7           0.599282297  ...       1       0.0      0.0    31.0      NaN
# 8           0.714932127  ...       1       0.0      0.0    12.0  14176.0
# 9           0.829545455  ...       1       0.0      0.0    13.0  22183.0
# 10    PrivacySuppressed  ...       2       0.0      0.0    12.0  21562.0
# 11          0.516129032  ...       1       0.0      0.0    41.0   1403.0
# 12    PrivacySuppressed  ...       2       0.0      0.0    32.0  21838.0
# 13          0.562656016  ...       3       0.0      0.0    12.0  21275.0
# 14    PrivacySuppressed  ...       1       0.0      0.0    32.0   4499.0
# 15          0.595375723  ...       1       0.0      0.0    32.0   6813.0
# 16              0.53125  ...       2       0.0      0.0    12.0  23970.0
# 17                  NaN  ...       1       0.0      0.0    13.0   3682.0
# 18                  NaN  ...       3       0.0      0.0    32.0   9463.0
# 19                  NaN  ...       1       0.0      0.0    41.0   3067.0
# 20          0.652849741  ...       1       0.0      0.0    32.0   7008.0
# 21                  NaN  ...       1       0.0      0.0    32.0   7688.0
# 22          0.529329609  ...       3       0.0      0.0    21.0  23186.0
# 23                 0.75  ...       2       0.0      0.0    12.0  19685.0
# 24    PrivacySuppressed  ...       2       0.0      0.0    13.0  11194.0
# 25                  NaN  ...       1       0.0      0.0    12.0   7222.0
# 26          0.672868217  ...       1       0.0      0.0    13.0  17139.0
# 27                  NaN  ...       1       0.0      0.0    32.0   3602.0
# 28           0.66025641  ...       1       0.0      0.0    12.0   9674.0
# 29           0.64057971  ...       1       0.0      0.0    41.0   5134.0
# ...                 ...  ...     ...       ...      ...     ...      ...
# 6672        0.543478261  ...       3       NaN      NaN     NaN      NaN
# 6673        0.656441718  ...       3       NaN      NaN     NaN      NaN
# 6674        0.607142857  ...       3       NaN      NaN     NaN      NaN
# 6675  PrivacySuppressed  ...       3       NaN      NaN     NaN      NaN
# 6676  PrivacySuppressed  ...       3       NaN      NaN     NaN      NaN
# 6677  PrivacySuppressed  ...       1       NaN      NaN     NaN      NaN
# 6678        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6679        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6680        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6681        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6682        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6683        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6684        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6685        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6686        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6687        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6688        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6689        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6690        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6691        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6692        0.529604068  ...       3       NaN      NaN     NaN      NaN
# 6693  PrivacySuppressed  ...       3       NaN      NaN     NaN      NaN
# 6694                NaN  ...       2       NaN      NaN     NaN      NaN
# 6695                NaN  ...       2       NaN      NaN     NaN      NaN
# 6696                NaN  ...       2       NaN      NaN     NaN      NaN
# 6697                NaN  ...       3       NaN      NaN     NaN      NaN
# 6698        0.598980065  ...       3       NaN      NaN     NaN      NaN
# 6699                NaN  ...       3       NaN      NaN     NaN      NaN
# 6700                NaN  ...       3       NaN      NaN     NaN      NaN
# 6701                NaN  ...       3       NaN      NaN     NaN      NaN
#
#       Degree_Type           Ownership      Regions        Locales Locale_Short
# 0        Graduate              Public   South East  City: Midsize         City
# 1        Graduate              Public   South East  City: Midsize         City
# 2        Graduate  Private non-profit   South East  City: Midsize         City
# 3        Graduate              Public   South East  City: Midsize         City
# 4        Graduate              Public   South East  City: Midsize         City
# 5        Graduate              Public   South East    City: Small         City
# 6      Associates              Public   South East  Town: Distant         Town
# 7       Bachelors              Public   South East   Town: Fringe         Town
# 8        Graduate              Public   South East  City: Midsize         City
# 9        Graduate              Public   South East    City: Small         City
# 10      Bachelors  Private non-profit   South East  City: Midsize         City
# 11     Associates              Public   South East  Rural: Fringe        Rural
# 12      Bachelors  Private non-profit   South East  Town: Distant         Town
# 13       Graduate  Private for-profit   South East  City: Midsize         City
# 14     Associates              Public   South East  Town: Distant         Town
# 15     Associates              Public   South East  Town: Distant         Town
# 16       Graduate  Private non-profit   South East  City: Midsize         City
# 17     Associates              Public   South East    City: Small         City
# 18    Certificate  Private for-profit   South East  Town: Distant         Town
# 19     Associates              Public   South East  Rural: Fringe        Rural
# 20     Associates              Public   South East  Town: Distant         Town
# 21     Associates              Public   South East  Town: Distant         Town
# 22       Graduate  Private for-profit   South East  Suburb: Large       Suburb
# 23      Bachelors  Private non-profit   South East  City: Midsize         City
# 24       Graduate  Private non-profit   South East    City: Small         City
# 25     Associates              Public   South East  City: Midsize         City
# 26       Graduate              Public   South East    City: Small         City
# 27     Associates              Public   South East  Town: Distant         Town
# 28     Associates              Public   South East  City: Midsize         City
# 29     Associates              Public   South East  Rural: Fringe        Rural
# ...           ...                 ...          ...            ...          ...
# 6672   Non-degree  Private for-profit   South East            NaN          NaN
# 6673   Non-degree  Private for-profit   South East            NaN          NaN
# 6674   Non-degree  Private for-profit   Rocky Mtns            NaN          NaN
# 6675   Non-degree  Private for-profit  Great Lakes            NaN          NaN
# 6676   Non-degree  Private for-profit     Mid East            NaN          NaN
# 6677   Non-degree              Public     Mid East            NaN          NaN
# 6678   Non-degree  Private for-profit   South East            NaN          NaN
# 6679   Non-degree  Private for-profit   South East            NaN          NaN
# 6680   Non-degree  Private for-profit   South East            NaN          NaN
# 6681   Non-degree  Private for-profit   South East            NaN          NaN
# 6682   Non-degree  Private for-profit   South East            NaN          NaN
# 6683   Non-degree  Private for-profit   South East            NaN          NaN
# 6684   Non-degree  Private for-profit   South East            NaN          NaN
# 6685   Non-degree  Private for-profit   South East            NaN          NaN
# 6686   Non-degree  Private for-profit   South East            NaN          NaN
# 6687   Non-degree  Private for-profit   South West            NaN          NaN
# 6688   Non-degree  Private for-profit   South West            NaN          NaN
# 6689   Non-degree  Private for-profit   South West            NaN          NaN
# 6690   Non-degree  Private for-profit   South West            NaN          NaN
# 6691   Non-degree  Private for-profit   South West            NaN          NaN
# 6692   Non-degree  Private for-profit   South West            NaN          NaN
# 6693   Non-degree  Private for-profit     Far West            NaN          NaN
# 6694   Non-degree  Private non-profit     Mid East            NaN          NaN
# 6695   Non-degree  Private non-profit   South East            NaN          NaN
# 6696   Non-degree  Private non-profit     Far West            NaN          NaN
# 6697   Non-degree  Private for-profit     Far West            NaN          NaN
# 6698   Non-degree  Private for-profit       Plains            NaN          NaN
# 6699   Non-degree  Private for-profit  Great Lakes            NaN          NaN
# 6700   Non-degree  Private for-profit     Far West            NaN          NaN
# 6701   Non-degree  Private for-profit     Far West            NaN          NaN
#
# [6702 rows x 24 columns]

# %%
# Display a regression plot for Tuition
sns.regplot(data=df,
            y='Tuition',
            x="SAT_AVG_ALL",
            marker='^',
            color='g')

plt.show()
plt.clf()

# %%
# Display the residual plot
sns.residplot(data=df,
              y='Tuition',
              x="SAT_AVG_ALL",
              color='g')

plt.show()
plt.clf()

# %%
# Plot a regression plot of Tuition and the US Regions
sns.regplot(data=df,
            y='Tuition',
            x="REGION")

plt.show()
plt.clf()

# %%
import numpy as np

# %%
# Create another plot that estimates the tuition by region
sns.regplot(data=df,
            y='Tuition',
            x="REGION",
            x_estimator=np.mean)

plt.show()
plt.clf()

# %%
# The final plot should include a line using a 3rd order polynomial
sns.regplot(data=df,
            y='Tuition',
            x="REGION",
            x_estimator=np.mean,
            order=3)

plt.show()
plt.clf()

# %%
# Create a scatter plot by disabling the regression line
sns.regplot(data=df,
            y='Tuition',
            x="UG",
            fit_reg=False)

plt.show()
plt.clf()

# %%
# Create a scatter plot and bin the data into 5 bins
sns.regplot(data=df,
            y='Tuition',
            x="UG",
            x_bins=5)

plt.show()
plt.clf()

# %%
# Create a regplot and bin the data into 8 bins
sns.regplot(data=df,
            y='Tuition',
            x="UG",
            x_bins=8)

plt.show()
plt.clf()

# %%
# Read in the DataFrame
df = pd.read_csv('C:\\Users\\Sayan\\OneDrive\\Documents\\Workspace\\FINAL_PYTHON\\datasets\\daily_show_guests_cleaned.csv')

# %%
# Create a crosstab table of the data and print it
pd_crosstab = pd.crosstab(df["Group"], df["YEAR"])
print(pd_crosstab)

# Plot a heatmap of the table
sns.heatmap(pd_crosstab)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

plt.show()
# Out:
# YEAR            1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# Group
# Academic           0     0     2     0     4     1    12     9    13     5
# Acting           108   100    92    84    74    51    44    44    25    26
# Advocacy           0     1     0     1     0     4     0     0     2     3
# Athletics          0     3     1     2     0     2     2     5     4     1
# Business           0     1     0     0     0     2     1     1     2     1
# Clergy             0     0     0     1     1     1     0     0     1     0
# Comedy            25    12    11     5    12     7     5     8     9     7
# Consultant         0     0     0     0     1     4     1     4     2     3
# Government         0     0     2     1     2     3     1     3     1     0
# Media             11    21    31    42    41    45    54    47    47    77
# Military           0     0     0     0     0     0     1     1     3     1
# Misc               0     0     2     1     1     0     4     3     2     2
# Musician          17    13    11    10     7     5    11     6     2     1
# Political Aide     0     1     1     2     1     2     3     3     2     6
# Politician         2    13     3     8    14    32    22    25    21    27
# Science            0     0     0     0     1     2     1     1     4     1
#
# YEAR            2009  2010  2011  2012  2013  2014  2015
# Group
# Academic          11     8    10     8     8    10     2
# Acting            22    45    42    33    60    47    33
# Advocacy           1     1     1     2     2     3     3
# Athletics          7     5     2     7     4     4     3
# Business           4     2     3     3     3     1     1
# Clergy             1     0     1     2     0     0     0
# Comedy             7     7     7     6     6     9     7
# Consultant         2     1     0     0     0     0     0
# Government         5     3     3     3     7     6     0
# Media             59    50    51    52    51    53    24
# Military           1     2     3     1     1     1     1
# Misc               5     4     5     6     2     5     3
# Musician           5     6     6     5     5     8     5
# Political Aide     3     2     1     1     3     2     3
# Politician        26    25    23    29    11    13    14
# Science            4     3     5     2     2     1     1

# %%
# Create the crosstab DataFrame
pd_crosstab = pd.crosstab(df["Group"], df["YEAR"])

# Plot a heatmap of the table
sns.heatmap(pd_crosstab, cbar=False, cmap="BuGn", linewidths=.3)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

# Show the plot
plt.show()
plt.clf()
